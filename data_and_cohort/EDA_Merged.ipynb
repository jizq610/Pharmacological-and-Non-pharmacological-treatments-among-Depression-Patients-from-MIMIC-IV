# %% [markdown]
# ### Importing Data

# %%
import pandas as pd

# %%
mimic = pd.read_csv("final_mimic.csv")

# %%
mimic.head()
# Out:
#    Unnamed: 0  subject_id   hadm_id  seq_num icd_code  icd_version  \
# 0           0    10002013  21763296       18     F329           10
# 1           1    10002013  21763296       18     F329           10
# 2           2    10002013  21763296       18     F329           10
# 3           3    10002013  21763296       18     F329           10
# 4           4    10002013  21763296       18     F329           10
#
#    anchor_age         note_id  note_seq  \
# 0          53  10002013-DS-12        12
# 1          53  10002013-DS-12        12
# 2          53  10002013-DS-12        12
# 3          53  10002013-DS-12        12
# 4          53  10002013-DS-12        12
#
#                                                 text   stay_id gender   race  \
# 0   \nName:  ___                 Unit No:   ___\n...  34931809      F  WHITE
# 1   \nName:  ___                 Unit No:   ___\n...  34931809      F  WHITE
# 2   \nName:  ___                 Unit No:   ___\n...  34931809      F  WHITE
# ...

# %%
mimic["text"]
# Out:
# 0       \nName:  ___                 Unit No:   ___\n...
# 1       \nName:  ___                 Unit No:   ___\n...
# 2       \nName:  ___                 Unit No:   ___\n...
# 3       \nName:  ___                 Unit No:   ___\n...
# 4       \nName:  ___                 Unit No:   ___\n...
#                              ...
# 196     \nName:  ___                Unit No:   ___\n ...
# 197     \nName:  ___                Unit No:   ___\n ...
# 198     \nName:  ___                Unit No:   ___\n ...
# 199     \nName:  ___                Unit No:   ___\n ...
# 200     \nName:  ___                Unit No:   ___\n ...
# Name: text, Length: 201, dtype: object

# %%
print(mimic.loc[2, "text"])
# Out:
#
# Name:  ___                 Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   F
#
# Service: MEDICINE
#
# Allergies:
# lisinopril
#
# Attending: ___
#
# Chief Complaint:
# Chest pain
#
# Major Surgical or Invasive Procedure:
# Cardiac cath (___)
#
#
# Past Medical History:
# -COPD
# -CAD s/p BMS proximal-LAD ___, DES to mid LAD ___, DES to edge
# ISR of mid LAD DES and stenosis distal to stent ___, DES to OM1
# ___, s/p 3 v CABG LIMA-LAD, SVG-OM1,
# ___
# -HFpEF
# -Depression
# -DM
# -GERD
# -Hypertension
# -Migraines
# -Chronic shoulder pain on narcotics
# -OSA
# -Peripheral neuropathy
# -Restless leg
#
# Social History:
# ___
# Family History:
# Patient was ward of the state, doesn't know full details of
# family history. Mother with possible alcohol abuse. Father
# deceased at ___ from Hodgkin's Disease per old records.
#
# Physical Exam:
# ADMISSION EXAM
# ...
# GENERAL:NAD AOx3 Pleasant woman.
# ...

# %% [markdown]
# ### Looking at Psychotherapy Mentions

# %%
mask = mimic["text"].str.contains("psychotherapy", case=False, na=False)
results = mimic[mask]

# %%
results.index
# Out:
# Index([  1907,   1908,   1909,   1910,   1911,   1912,   1913,   2132,   2133,
#          2134,
#        ...
#        219136, 219137, 219138, 219139, 219140, 219141, 219142, 219143, 219144,
#        219145],
#       dtype='int64', length=627)

# %%
print(results.loc[2132, "text"])
# Out:
#
# Name:  ___                  Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   F
#
# Service: PSYCHIATRY
#
# Allergies:
# No Known Allergies / Adverse Drug Reactions
#
# Attending: ___.
#
# Chief Complaint:
# CHIEF COMPLAINT: "I just couldn't take it anymore."
#
# Major Surgical or Invasive Procedure:
# None
#
#
# History of Present Illness:
# ___ is a ___ woman with a history of
# adolescent-onset depression who self-presented to the ED
# reporting worsening depression with suicidal thoughts.
# .
# Pt states that she was at an appointment with her therapist
# today, and they decided together that she could benefit from a
# higher level of care. The pt states that she has felt
# increasingly depressed since ___ in the setting of many deaths
# in her family as well as the failing health of an aunt to whom
# she is close; this aunt is now living with the pt and her
# ...

# %% [markdown]
# ### Looking at only notes from Psychiatry

# %%
psych_mask = mimic["text"].str.contains("Service: PSYCHIATRY", case=False, na=False)
psych = mimic[psych_mask]

# %%
psych.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 2132 to 219354
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      299 non-null    int64
#  1   subject_id      299 non-null    int64
#  2   hadm_id         299 non-null    int64
#  3   seq_num         299 non-null    int64
#  4   icd_code        299 non-null    object
#  5   icd_version     299 non-null    int64
#  6   anchor_age      299 non-null    int64
#  7   note_id         299 non-null    object
#  8   note_seq        299 non-null    int64
#  9   text            299 non-null    object
#  10  stay_id         299 non-null    int64
#  11  gender          299 non-null    object
#  12  race            299 non-null    object
#  13  name            299 non-null    object
#  14  gsn             299 non-null    int64
#  15  ndc             299 non-null    int64
#  16  etc_rn          299 non-null    int64
# ...

# %%
psych.head(15)
# Out:
#        Unnamed: 0  subject_id   hadm_id  seq_num icd_code  icd_version  \
# 2132         2132    10106189  21900475        1     F339           10
# 2133         2133    10106189  21900475        1     F339           10
# 2134         2134    10106189  21900475        1     F339           10
# 2135         2135    10106189  21900475        1     F339           10
# 2136         2136    10106189  21900475        1     F339           10
# 7616         7616    10357715  27417870        1     F331           10
# 8710         8710    10429993  27060341        1     F339           10
# 8711         8711    10429993  27060341        1     F339           10
# 8712         8712    10429993  27060341        1     F339           10
# 8713         8713    10429993  27060341        1     F339           10
# 8714         8714    10429993  27060341        1     F339           10
# 8715         8715    10429993  27060341        1     F339           10
# ...

# %%
print(psych.loc[8710, "text"])
# Out:
#
# Name:  ___            Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   F
#
# Service: PSYCHIATRY
#
# Allergies:
# No Known Allergies / Adverse Drug Reactions
#
# Attending: ___.
#
# Chief Complaint:
# "I keep having suicidal thoughts and I'm worried
# something is going to happen."
#
# Major Surgical or Invasive Procedure:
# none
#
#
# History of Present Illness:
# Per Deac 4 admission interview, Dr. ___ ___
# "Briefly, Ms. ___ is a ___ year old woman with psychiatric
# history of major depressive disorder and anxiety who was BIB EMS
# from her ___ HRI partial program after endorsing worsening
# suicidal thoughts. Of note, Ms. ___ was recently admitted
# to ___ for inpatient psych treatment following an
# intentional overdose; she was discharged on ___
# (refer to the discharge summary by Dr. ___ ___.
#
#
# On interview, in the ED, "Ms. ___ states she was anxious
# ...
